# %% [markdown]
# https://store.steampowered.com/tags/en/Action/
#
# 1. Try extracting the names of the top games from this page.
#
# 2. What tags contain the prices? Can you extract the price information?
#
# 3. Get all of the header tags on the page.
#
# 4. Can you get the text from each span tag with class equal to "top_tag"?
#
# 5. Under the "Narrow by Tag" section, there are a collection of tags (e.g. "Indie", "Adventure", etc.). Write code to return these tags.
#
# 6. What else can be scraped from this webpage or others on the site?

# %%
import requests
from bs4 import BeautifulSoup

# %%
base_url = 'https://store.steampowered.com/tags/en/Action/'

# %%
r = requests.get(base_url)
r
# Out:
# <Response [200]>

# %%
html = r.content

# %%
soup = BeautifulSoup(html, 'lxml')

# %%
with open('steamapps.html', 'wb') as steam_file:
    steam_file.write(soup.prettify('utf-8'))

# %%
new_releases = soup.find('div', {'id':'NewReleasesRows'}).find_all('a', class_='tab_item')

# %%
new_releases[0].find('div', class_='tab_item_name').text
# Out:
# 'Streets of Rage 4'

# %% [markdown]
# ### Extract Top Rated Games
#
# By inspecting html, we can find that top rated games are under `div` tag with class `TopRatedRows`.
#
# Under that, every game comes under `a` tag.

# %%
top_rated = soup.find('div', {'id':'TopRatedRows'}).find_all('a', class_='tab_item')

# %%
top_rated
# Out:
# [<a class="tab_item" data-ds-appid="730" data-ds-crtrids="[4]" data-ds-descids="[2,5]" data-ds-itemkey="App_730" data-ds-tagids="[1663,1774,3859,3878,19,5711,5055]" href="https://store.steampowered.com/app/730/CounterStrike_Global_Offensive/?snr=1_241_4_action_tab-TopRated" onmouseout="HideGameHover( this, event, 'global_hover' )" onmouseover="GameHover( this, event, 'global_hover', {&quot;type&quot;:&quot;app&quot;,&quot;id&quot;:730,&quot;params&quot;:{&quot;bDisableHover&quot;:false},&quot;public&quot;:1,&quot;v6&quot;:1} );">
#  <div class="tab_item_cap">
#  <img class="tab_item_cap_img" src="https://steamcdn-a.akamaihd.net/steam/apps/730/capsule_184x69.jpg?t=1585696022"/>
#  </div>
#  <div class="discount_block tab_item_discount no_discount" data-price-final="104900"><div class="discount_prices"><div class="discount_final_price">Free to Play</div></div></div> <div class="tab_item_content">
#  <div class="tab_item_name">Counter-Strike: Global Offensive</div>
#  <div class="tab_item_details">
#  <span class="platform_img win"></span><span class="platform_img mac"></span><span class="platform_img linux"></span> <div class="tab_item_top_tags"><span class="top_tag">FPS</span><span class="top_tag">, Shooter</span><span class="top_tag">, Multiplayer</span><span class="top_tag">, Competitive</span></div>
#  </div>
#  </div>
#  <div style="clear: both;"></div>
#  </a>,
#  <a class="tab_item" data-ds-appid="359550" data-ds-crtrids="[33075774]" data-ds-itemkey="App_359550" data-ds-tagids="[1663,620519,3859,1708,1774,5711,19]" href="https://store.steampowered.com/app/359550/Tom_Clancys_Rainbow_Six_Siege/?snr=1_241_4_action_tab-TopRated" onmouseout="HideGameHover( this, event, 'global_hover' )" onmouseover="GameHover( this, event, 'global_hover', {&quot;type&quot;:&quot;app&quot;,&quot;id&quot;:359550,&quot;params&quot;:{&quot;bDisableHover&quot;:false},&quot;public&quot;:1,&quot;v6&quot;:1} );">
#  <div class="tab_item_cap">
#  <img class="tab_item_cap_img" src="https://steamcdn-a.akamaihd.net/steam/apps/359550/capsule_184x69.jpg?t=1585594789"/>
#  </div>
#  <div class="discount_block tab_item_discount no_discount" data-price-final="99900"><div class="discount_prices"><div class="discount_final_price">₹ 999</div></div></div> <div class="tab_item_content">
#  <div class="tab_item_name">Tom Clancy's Rainbow Six® Siege</div>
#  <div class="tab_item_details">
#  <span class="platform_img win"></span> <div class="tab_item_top_tags"><span class="top_tag">FPS</span><span class="top_tag">, Hero Shooter</span><span class="top_tag">, Multiplayer</span><span class="top_tag">, Tactical</span></div>
#  </div>
#  </div>
#  <div style="clear: both;"></div>
#  </a>,
#  <a class="tab_item" data-ds-appid="230410" data-ds-crtrids="[32978945]" data-ds-descids="[2,5]" data-ds-itemkey="App_230410" data-ds-tagids="[113,353880,19,1685,3859,3814,3942]" href="https://store.steampowered.com/app/230410/Warframe/?snr=1_241_4_action_tab-TopRated" onmouseout="HideGameHover( this, event, 'global_hover' )" onmouseover="GameHover( this, event, 'global_hover', {&quot;type&quot;:&quot;app&quot;,&quot;id&quot;:230410,&quot;params&quot;:{&quot;bDisableHover&quot;:false},&quot;public&quot;:1,&quot;v6&quot;:1} );">
#  <div class="tab_item_cap">
#  <img class="tab_item_cap_img" src="https://steamcdn-a.akamaihd.net/steam/apps/230410/capsule_184x69.jpg?t=1588019344"/>
#  </div>
#  <div class="discount_block tab_item_discount no_discount" data-price-final="0"><div class="discount_prices"><div class="discount_final_price">Free to Play</div></div></div> <div class="tab_item_content">
#  <div class="tab_item_name">Warframe</div>
#  <div class="tab_item_details">
#  <span class="platform_img win"></span> <div class="tab_item_top_tags"><span class="top_tag">Free to Play</span><span class="top_tag">, Looter Shooter</span><span class="top_tag">, Action</span><span class="top_tag">, Co-op</span></div>
#  </div>
#  </div>
#  <div style="clear: both;"></div>
#  </a>,
#  <a class="tab_item" data-ds-appid="550" data-ds-crtrids="[4]" data-ds-descids="[2,5]" data-ds-itemkey="App_550" data-ds-tagids="[1659,1685,1663,3859,1774,19,3843]" href="https://store.steampowered.com/app/550/Left_4_Dead_2/?snr=1_241_4_action_tab-TopRated" onmouseout="HideGameHover( this, event, 'global_hover' )" onmouseover="GameHover( this, event, 'global_hover', {&quot;type&quot;:&quot;app&quot;,&quot;id&quot;:550,&quot;params&quot;:{&quot;bDisableHover&quot;:false},&quot;public&quot;:1,&quot;v6&quot;:1} );">
#  <div class="tab_item_cap">
#  <img class="tab_item_cap_img" src="https://steamcdn-a.akamaihd.net/steam/apps/550/capsule_184x69.jpg?t=1587582634"/>
#  </div>
#  <div class="discount_block tab_item_discount no_discount" data-price-final="34900"><div class="discount_prices"><div class="discount_final_price">₹ 349</div></div></div> <div class="tab_item_content">
#  <div class="tab_item_name">Left 4 Dead 2</div>
#  <div class="tab_item_details">
#  <span class="platform_img win"></span><span class="platform_img mac"></span><span class="platform_img linux"></span> <div class="tab_item_top_tags"><span class="top_tag">Zombies</span><span class="top_tag">, Co-op</span><span class="top_tag">, FPS</span><span class="top_tag">, Multiplayer</span></div>
#  </div>
#  </div>
#  <div style="clear: both;"></div>
#  </a>,
#  <a class="tab_item" data-ds-appid="10" data-ds-crtrids="[4]" data-ds-descids="[2,5]" data-ds-itemkey="App_10" data-ds-tagids="[19,1663,3859,1774,1693,5711,3839]" href="https://store.steampowered.com/app/10/CounterStrike/?snr=1_241_4_action_tab-TopRated" onmouseout="HideGameHover( this, event, 'global_hover' )" onmouseover="GameHover( this, event, 'global_hover', {&quot;type&quot;:&quot;app&quot;,&quot;id&quot;:10,&quot;params&quot;:{&quot;bDisableHover&quot;:false},&quot;public&quot;:1,&quot;v6&quot;:1} );">
#  <div class="tab_item_cap">
#  <img class="tab_item_cap_img" src="https://steamcdn-a.akamaihd.net/steam/apps/10/capsule_184x69.jpg?t=1568751918"/>
#  </div>
#  <div class="discount_block tab_item_discount no_discount" data-price-final="34900"><div class="discount_prices"><div class="discount_final_price">₹ 349</div></div></div> <div class="tab_item_content">
#  <div class="tab_item_name">Counter-Strike</div>
#  <div class="tab_item_details">
#  <span class="platform_img win"></span><span class="platform_img mac"></span><span class="platform_img linux"></span> <div class="tab_item_top_tags"><span class="top_tag">Action</span><span class="top_tag">, FPS</span><span class="top_tag">, Multiplayer</span><span class="top_tag">, Shooter</span></div>
#  </div>
#  </div>
#  <div style="clear: both;"></div>
#  </a>,
#  <a class="tab_item" data-ds-appid="49520" data-ds-crtrids="[31936442,2428135,33338128]" data-ds-itemkey="App_49520" data-ds-tagids="[4236,1774,19,3859,1685,353880,1663]" href="https://store.steampowered.com/app/49520/Borderlands_2/?snr=1_241_4_action_tab-TopRated" onmouseout="HideGameHover( this, event, 'global_hover' )" onmouseover="GameHover( this, event, 'global_hover', {&quot;type&quot;:&quot;app&quot;,&quot;id&quot;:49520,&quot;params&quot;:{&quot;bDisableHover&quot;:false},&quot;public&quot;:1,&quot;v6&quot;:1} );">
#  <div class="tab_item_cap">
#  <img class="tab_item_cap_img" src="https://steamcdn-a.akamaihd.net/steam/apps/49520/capsule_184x69.jpg?t=1582831290"/>
#  </div>
#  <div class="discount_block tab_item_discount no_discount" data-price-final="99900"><div class="discount_prices"><div class="discount_final_price">₹ 999</div></div></div> <div class="tab_item_content">
#  <div class="tab_item_name">Borderlands 2</div>
#  <div class="tab_item_details">
#  <span class="platform_img win"></span><span class="platform_img mac"></span><span class="platform_img linux"></span> <div class="tab_item_top_tags"><span class="top_tag">Loot</span><span class="top_tag">, Shooter</span><span class="top_tag">, Action</span><span class="top_tag">, Multiplayer</span></div>
#  </div>
#  </div>
#  <div style="clear: both;"></div>
#  </a>,
#  <a class="tab_item" data-ds-appid="203160" data-ds-crtrids="[1012195,33075928,33824648,35801496]" data-ds-itemkey="App_203160" data-ds-tagids="[21,19,7208,1697,21722,4182,3814]" href="https://store.steampowered.com/app/203160/Tomb_Raider/?snr=1_241_4_action_tab-TopRated" onmouseout="HideGameHover( this, event, 'global_hover' )" onmouseover="GameHover( this, event, 'global_hover', {&quot;type&quot;:&quot;app&quot;,&quot;id&quot;:203160,&quot;params&quot;:{&quot;bDisableHover&quot;:false},&quot;public&quot;:1,&quot;v6&quot;:1} );">
#  <div class="tab_item_cap">
#  <img class="tab_item_cap_img" src="https://steamcdn-a.akamaihd.net/steam/apps/203160/capsule_184x69.jpg?t=1584650700"/>
#  </div>
#  <div class="discount_block empty tab_item_discount"></div> <div class="tab_item_content">
#  <div class="tab_item_name">Tomb Raider</div>
#  <div class="tab_item_details">
#  <span class="platform_img win"></span><span class="platform_img mac"></span><span class="platform_img linux"></span> <div class="tab_item_top_tags"><span class="top_tag">Adventure</span><span class="top_tag">, Action</span><span class="top_tag">, Female Protagonist</span><span class="top_tag">, Third Person</span></div>
#  </div>
#  </div>
#  <div style="clear: both;"></div>
#  </a>,
#  <a class="tab_item" data-ds-appid="218620" data-ds-crtrids="[32824912]" data-ds-itemkey="App_218620" data-ds-tagids="[1685,19,1663,1680,353880,3843,1687]" href="https://store.steampowered.com/app/218620/PAYDAY_2/?snr=1_241_4_action_tab-TopRated" onmouseout="HideGameHover( this, event, 'global_hover' )" onmouseover="GameHover( this, event, 'global_hover', {&quot;type&quot;:&quot;app&quot;,&quot;id&quot;:218620,&quot;params&quot;:{&quot;bDisableHover&quot;:false},&quot;public&quot;:1,&quot;v6&quot;:1} );">
#  <div class="tab_item_cap">
#  <img class="tab_item_cap_img" src="https://steamcdn-a.akamaihd.net/steam/apps/218620/capsule_184x69.jpg?t=1584629114"/>
#  </div>
#  <div class="discount_block tab_item_discount no_discount" data-price-final="34900"><div class="discount_prices"><div class="discount_final_price">₹ 349</div></div></div> <div class="tab_item_content">
#  <div class="tab_item_name">PAYDAY 2</div>
#  <div class="tab_item_details">
#  <span class="platform_img win"></span><span class="platform_img linux"></span><span class="vr_supported">VR Supported</span> <div class="tab_item_top_tags"><span class="top_tag">Co-op</span><span class="top_tag">, Action</span><span class="top_tag">, FPS</span><span class="top_tag">, Heist</span></div>
#  </div>
#  </div>
#  <div style="clear: both;"></div>
#  </a>,
#  <a class="tab_item" data-ds-appid="1085660" data-ds-itemkey="App_1085660" data-ds-tagids="[113,353880,1663,3859,19,3843,21]" href="https://store.steampowered.com/app/1085660/Destiny_2/?snr=1_241_4_action_tab-TopRated" onmouseout="HideGameHover( this, event, 'global_hover' )" onmouseover="GameHover( this, event, 'global_hover', {&quot;type&quot;:&quot;app&quot;,&quot;id&quot;:1085660,&quot;params&quot;:{&quot;bDisableHover&quot;:false},&quot;public&quot;:1,&quot;v6&quot;:1} );">
#  <div class="tab_item_cap">
#  <img class="tab_item_cap_img" src="https://steamcdn-a.akamaihd.net/steam/apps/1085660/capsule_184x69.jpg?t=1583858222"/>
#  </div>
#  <div class="discount_block tab_item_discount no_discount" data-price-final="0"><div class="discount_prices"><div class="discount_final_price">Free To Play</div></div></div> <div class="tab_item_content">
#  <div class="tab_item_name">Destiny 2</div>
#  <div class="tab_item_details">
#  <span class="platform_img win"></span> <div class="tab_item_top_tags"><span class="top_tag">Free to Play</span><span class="top_tag">, Looter Shooter</span><span class="top_tag">, FPS</span><span class="top_tag">, Multiplayer</span></div>
#  </div>
#  </div>
#  <div style="clear: both;"></div>
#  </a>,
#  <a class="tab_item" data-ds-appid="240" data-ds-crtrids="[4]" data-ds-descids="[2,5]" data-ds-itemkey="App_240" data-ds-tagids="[1774,19,1663,3859,5711,3839,1708]" href="https://store.steampowered.com/app/240/CounterStrike_Source/?snr=1_241_4_action_tab-TopRated" onmouseout="HideGameHover( this, event, 'global_hover' )" onmouseover="GameHover( this, event, 'global_hover', {&quot;type&quot;:&quot;app&quot;,&quot;id&quot;:240,&quot;params&quot;:{&quot;bDisableHover&quot;:false},&quot;public&quot;:1,&quot;v6&quot;:1} );">
#  <div class="tab_item_cap">
#  <img class="tab_item_cap_img" src="https://steamcdn-a.akamaihd.net/steam/apps/240/capsule_184x69.jpg?t=1580852525"/>
#  </div>
#  <div class="discount_block tab_item_discount no_discount" data-price-final="34900"><div class="discount_prices"><div class="discount_final_price">₹ 349</div></div></div> <div class="tab_item_content">
#  <div class="tab_item_name">Counter-Strike: Source</div>
#  <div class="tab_item_details">
#  <span class="platform_img win"></span><span class="platform_img mac"></span><span class="platform_img linux"></span> <div class="tab_item_top_tags"><span class="top_tag">Shooter</span><span class="top_tag">, Action</span><span class="top_tag">, FPS</span><span class="top_tag">, Multiplayer</span></div>
#  </div>
#  </div>
#  <div style="clear: both;"></div>
#  </a>,
#  <a class="tab_item" data-ds-appid="220" data-ds-crtrids="[4,33078398]" data-ds-itemkey="App_220" data-ds-tagids="[1663,19,3942,1693,5144,4182,1742]" href="https://store.steampowered.com/app/220/HalfLife_2/?snr=1_241_4_action_tab-TopRated" onmouseout="HideGameHover( this, event, 'global_hover' )" onmouseover="GameHover( this, event, 'global_hover', {&quot;type&quot;:&quot;app&quot;,&quot;id&quot;:220,&quot;params&quot;:{&quot;bDisableHover&quot;:false},&quot;public&quot;:1,&quot;v6&quot;:1} );">
#  <div class="tab_item_cap">
#  <img class="tab_item_cap_img" src="https://steamcdn-a.akamaihd.net/steam/apps/220/capsule_184x69.jpg?t=1587513163"/>
#  </div>
#  <div class="discount_block tab_item_discount no_discount" data-price-final="34900"><div class="discount_prices"><div class="discount_final_price">₹ 349</div></div></div> <div class="tab_item_content">
#  <div class="tab_item_name">Half-Life 2</div>
#  <div class="tab_item_details">
#  <span class="platform_img win"></span><span class="platform_img mac"></span><span class="platform_img linux"></span> <div class="tab_item_top_tags"><span class="top_tag">FPS</span><span class="top_tag">, Action</span><span class="top_tag">, Sci-fi</span><span class="top_tag">, Classic</span></div>
#  </div>
#  </div>
#  <div style="clear: both;"></div>
#  </a>,
#  <a class="tab_item" data-ds-appid="8870" data-ds-crtrids="[27977419,2428135,33339561,31936442]" data-ds-itemkey="App_8870" data-ds-tagids="[1663,1742,19,4182,1777,5144,4166]" href="https://store.steampowered.com/app/8870/BioShock_Infinite/?snr=1_241_4_action_tab-TopRated" onmouseout="HideGameHover( this, event, 'global_hover' )" onmouseover="GameHover( this, event, 'global_hover', {&quot;type&quot;:&quot;app&quot;,&quot;id&quot;:8870,&quot;params&quot;:{&quot;bDisableHover&quot;:false},&quot;public&quot;:1,&quot;v6&quot;:1} );">
#  <div class="tab_item_cap">
#  <img class="tab_item_cap_img" src="https://steamcdn-a.akamaihd.net/steam/apps/8870/capsule_184x69.jpg?t=1582076053"/>
#  </div>
#  <div class="discount_block tab_item_discount no_discount" data-price-final="149900"><div class="discount_prices"><div class="discount_final_price">₹ 1,499</div></div></div> <div class="tab_item_content">
#  <div class="tab_item_name">BioShock Infinite</div>
#  <div class="tab_item_details">
#  <span class="platform_img win"></span><span class="platform_img mac"></span><span class="platform_img linux"></span> <div class="tab_item_top_tags"><span class="top_tag">FPS</span><span class="top_tag">, Story Rich</span><span class="top_tag">, Action</span><span class="top_tag">, Singleplayer</span></div>
#  </div>
#  </div>
#  <div style="clear: both;"></div>
#  </a>,
#  <a class="tab_item" data-ds-appid="632360" data-ds-crtrids="[35646051]" data-ds-itemkey="App_632360" data-ds-tagids="[3814,42804,19,3859,3959,1685,353880]" href="https://store.steampowered.com/app/632360/Risk_of_Rain_2/?snr=1_241_4_action_tab-TopRated" onmouseout="HideGameHover( this, event, 'global_hover' )" onmouseover="GameHover( this, event, 'global_hover', {&quot;type&quot;:&quot;app&quot;,&quot;id&quot;:632360,&quot;params&quot;:{&quot;bDisableHover&quot;:false},&quot;public&quot;:1,&quot;v6&quot;:1} );">
#  <div class="tab_item_cap">
#  <img class="tab_item_cap_img" src="https://steamcdn-a.akamaihd.net/steam/apps/632360/capsule_184x69.jpg?t=1586458597"/>
#  </div>
#  <div class="discount_block tab_item_discount no_discount" data-price-final="71900"><div class="discount_prices"><div class="discount_final_price">₹ 719</div></div></div> <div class="tab_item_content">
#  <div class="tab_item_name">Risk of Rain 2</div>
#  <div class="tab_item_details">
#  <span class="platform_img win"></span> <div class="tab_item_top_tags"><span class="top_tag">Third-Person Shooter</span><span class="top_tag">, Action Roguelike</span><span class="top_tag">, Action</span><span class="top_tag">, Multiplayer</span></div>
#  </div>
#  </div>
#  <div style="clear: both;"></div>
#  </a>,
#  <a class="tab_item" data-ds-appid="48700" data-ds-crtrids="[33089344]" data-ds-itemkey="App_48700" data-ds-tagids="[4172,122,1695,9,3810,19,3859]" href="https://store.steampowered.com/app/48700/Mount__Blade_Warband/?snr=1_241_4_action_tab-TopRated" onmouseout="HideGameHover( this, event, 'global_hover' )" onmouseover="GameHover( this, event, 'global_hover', {&quot;type&quot;:&quot;app&quot;,&quot;id&quot;:48700,&quot;params&quot;:{&quot;bDisableHover&quot;:false},&quot;public&quot;:1,&quot;v6&quot;:1} );">
#  <div class="tab_item_cap">
#  <img class="tab_item_cap_img" src="https://steamcdn-a.akamaihd.net/steam/apps/48700/capsule_184x69.jpg?t=1588933602"/>
#  </div>
#  <div class="discount_block tab_item_discount no_discount" data-price-final="69900"><div class="discount_prices"><div class="discount_final_price">₹ 699</div></div></div> <div class="tab_item_content">
#  <div class="tab_item_name">Mount &amp; Blade: Warband</div>
#  <div class="tab_item_details">
#  <span class="platform_img win"></span><span class="platform_img mac"></span><span class="platform_img linux"></span> <div class="tab_item_top_tags"><span class="top_tag">Medieval</span><span class="top_tag">, RPG</span><span class="top_tag">, Open World</span><span class="top_tag">, Strategy</span></div>
#  </div>
#  </div>
#  <div style="clear: both;"></div>
#  </a>,
#  <a class="tab_item" data-ds-appid="582010" data-ds-crtrids="[33273264,34827959]" data-ds-itemkey="App_582010" data-ds-tagids="[1685,3859,19,1695,122,1697,4747]" href="https://store.steampowered.com/app/582010/MONSTER_HUNTER_WORLD/?snr=1_241_4_action_tab-TopRated" onmouseout="HideGameHover( this, event, 'global_hover' )" onmouseover="GameHover( this, event, 'global_hover', {&quot;type&quot;:&quot;app&quot;,&quot;id&quot;:582010,&quot;params&quot;:{&quot;bDisableHover&quot;:false},&quot;public&quot;:1,&quot;v6&quot;:1} );">
#  <div class="tab_item_cap">
#  <img class="tab_item_cap_img" src="https://steamcdn-a.akamaihd.net/steam/apps/582010/capsule_184x69.jpg?t=1587600484"/>
#  </div>
#  <div class="discount_block tab_item_discount no_discount" data-price-final="249700"><div class="discount_prices"><div class="discount_final_price">₹ 2,497</div></div></div> <div class="tab_item_content">
#  <div class="tab_item_name">MONSTER HUNTER: WORLD</div>
#  <div class="tab_item_details">
#  <span class="platform_img win"></span> <div class="tab_item_top_tags"><span class="top_tag">Co-op</span><span class="top_tag">, Multiplayer</span><span class="top_tag">, Action</span><span class="top_tag">, Open World</span></div>
#  </div>
#  </div>
#  <div style="clear: both;"></div>
#  </a>]

# %%
len(top_rated)
# Out:
# 15

# %%
top_rated_games = [game.find('div', class_='tab_item_name').text for game in top_rated]

# %%
top_rated_games
# Out:
# ['Counter-Strike: Global Offensive',
#  "Tom Clancy's Rainbow Six® Siege",
#  'Warframe',
#  'Left 4 Dead 2',
#  'Counter-Strike',
#  'Borderlands 2',
#  'Tomb Raider',
#  'PAYDAY 2',
#  'Destiny 2',
#  'Counter-Strike: Source',
#  'Half-Life 2',
#  'BioShock Infinite',
#  'Risk of Rain 2',
#  'Mount & Blade: Warband',
#  'MONSTER HUNTER: WORLD']

# %% [markdown]
# ### Price of game
#
# In every `a` tag, price is given under `div` tag with class = `discount_final_price`

# %%
top_rated_prices = []
for game in top_rated:
    try:
        top_rated_prices.append(game.find('div', class_='discount_final_price').text)
        
    except AttributeError:
        top_rated_prices.append(None)

# %%
top_rated_prices
# Out:
# ['Free to Play',
#  '₹ 999',
#  'Free to Play',
#  '₹ 349',
#  '₹ 349',
#  '₹ 999',
#  None,
#  '₹ 349',
#  'Free To Play',
#  '₹ 349',
#  '₹ 349',
#  '₹ 1,499',
#  '₹ 719',
#  '₹ 699',
#  '₹ 2,497']

# %% [markdown]
# ### Get all of the header tags
#
# There are only `h2` headers are present on page

# %%
h2_tags = soup.find_all('h2')

# %%
h2_headings = [tag.text.strip() for tag in h2_tags]

# %%
h2_headings
# Out:
# ['Browsing Action',
#  'Daily Deal',
#  'Spotlight',
#  'Weekend Deal',
#  'Weekend Deal',
#  'Weekend Deal',
#  'Narrow By Tag',
#  'Recommended Specials',
#  'Games streaming now']

# %% [markdown]
# ### Get the text from each span tag with class equal to "top_tag"

# %%
span_top_tags = soup.find_all('span', class_ = 'top_tag')
span_top_tags
# Out:
# [<span class="top_tag">Action</span>,
#  <span class="top_tag">, Indie</span>,
#  <span class="top_tag">, Beat 'em up</span>,
#  <span class="top_tag">, Adventure</span>,
#  <span class="top_tag">Adventure</span>,
#  <span class="top_tag">, RPG</span>,
#  <span class="top_tag">, Massively Multiplayer</span>,
#  <span class="top_tag">, Action</span>,
#  <span class="top_tag">Action</span>,
#  <span class="top_tag">, Indie</span>,
#  <span class="top_tag">, Adventure</span>,
#  <span class="top_tag">, RPG</span>,
#  <span class="top_tag">Action</span>,
#  <span class="top_tag">, Indie</span>,
#  <span class="top_tag">, Retro</span>,
#  <span class="top_tag">, Old School</span>,
#  <span class="top_tag">Indie</span>,
#  <span class="top_tag">, Action</span>,
#  <span class="top_tag">, Adventure</span>,
#  <span class="top_tag">, Gore</span>,
#  <span class="top_tag">Action</span>,
#  <span class="top_tag">, Indie</span>,
#  <span class="top_tag">, RPG</span>,
#  <span class="top_tag">, Violent</span>,
#  <span class="top_tag">Free to Play</span>,
#  <span class="top_tag">, Massively Multiplayer</span>,
#  <span class="top_tag">, Action</span>,
#  <span class="top_tag">, Strategy</span>,
#  <span class="top_tag">Simulation</span>,
#  <span class="top_tag">, Action</span>,
#  <span class="top_tag">, Indie</span>,
#  <span class="top_tag">, Adventure</span>,
#  <span class="top_tag">Casual</span>,
#  <span class="top_tag">, Indie</span>,
#  <span class="top_tag">, Action</span>,
#  <span class="top_tag">, Simulation</span>,
#  <span class="top_tag">Action</span>,
#  <span class="top_tag">, Adventure</span>,
#  <span class="top_tag">, Indie</span>,
#  <span class="top_tag">, Gore</span>,
#  <span class="top_tag">Massively Multiplayer</span>,
#  <span class="top_tag">, Simulation</span>,
#  <span class="top_tag">, Action</span>,
#  <span class="top_tag">, VR</span>,
#  <span class="top_tag">RPG</span>,
#  <span class="top_tag">, Action</span>,
#  <span class="top_tag">, Online Co-Op</span>,
#  <span class="top_tag">, Looter Shooter</span>,
#  <span class="top_tag">Action</span>,
#  <span class="top_tag">, Zombies</span>,
#  <span class="top_tag">, Horror</span>,
#  <span class="top_tag">, Female Protagonist</span>,
#  <span class="top_tag">Action</span>,
#  <span class="top_tag">, Anime</span>,
#  <span class="top_tag">, Fighting</span>,
#  <span class="top_tag">, 2D Fighter</span>,
#  <span class="top_tag">Action</span>,
#  <span class="top_tag">, Adventure</span>,
#  <span class="top_tag">, Nudity</span>,
#  <span class="top_tag">, Early Access</span>,
#  <span class="top_tag">Action</span>,
#  <span class="top_tag">, Multiplayer</span>,
#  <span class="top_tag">, Hunting</span>,
#  <span class="top_tag">, Co-op</span>,
#  <span class="top_tag">Action</span>,
#  <span class="top_tag">, Indie</span>,
#  <span class="top_tag">, Beat 'em up</span>,
#  <span class="top_tag">, Adventure</span>,
#  <span class="top_tag">RPG</span>,
#  <span class="top_tag">, Action</span>,
#  <span class="top_tag">, Online Co-Op</span>,
#  <span class="top_tag">, Looter Shooter</span>,
#  <span class="top_tag">Co-op</span>,
#  <span class="top_tag">, Multiplayer</span>,
#  <span class="top_tag">, Action</span>,
#  <span class="top_tag">, Open World</span>,
#  <span class="top_tag">Action</span>,
#  <span class="top_tag">, Masterpiece</span>,
#  <span class="top_tag">, FPS</span>,
#  <span class="top_tag">, Great Soundtrack</span>,
#  <span class="top_tag">Action</span>,
#  <span class="top_tag">, Anime</span>,
#  <span class="top_tag">, Fighting</span>,
#  <span class="top_tag">, 2D Fighter</span>,
#  <span class="top_tag">Open World</span>,
#  <span class="top_tag">, Action</span>,
#  <span class="top_tag">, Multiplayer</span>,
#  <span class="top_tag">, Automobile Sim</span>,
#  <span class="top_tag">Adventure</span>,
#  <span class="top_tag">, Action</span>,
#  <span class="top_tag">, Open World</span>,
#  <span class="top_tag">, Masterpiece</span>,
#  <span class="top_tag">Action Roguelike</span>,
#  <span class="top_tag">, Action</span>,
#  <span class="top_tag">, RPG</span>,
#  <span class="top_tag">, Indie</span>,
#  <span class="top_tag">Souls-like</span>,
#  <span class="top_tag">, Action</span>,
#  <span class="top_tag">, RPG</span>,
#  <span class="top_tag">, Adventure</span>,
#  <span class="top_tag">Action</span>,
#  <span class="top_tag">, Zombies</span>,
#  <span class="top_tag">, Horror</span>,
#  <span class="top_tag">, Female Protagonist</span>,
#  <span class="top_tag">Action</span>,
#  <span class="top_tag">, Multiplayer</span>,
#  <span class="top_tag">, FPS</span>,
#  <span class="top_tag">, Shooter</span>,
#  <span class="top_tag">Action</span>,
#  <span class="top_tag">, Adventure</span>,
#  <span class="top_tag">, Star Wars</span>,
#  <span class="top_tag">, Souls-like</span>,
#  <span class="top_tag">Masterpiece</span>,
#  <span class="top_tag">, Action</span>,
#  <span class="top_tag">, Adventure</span>,
#  <span class="top_tag">, VR</span>,
#  <span class="top_tag">Action</span>,
#  <span class="top_tag">, FPS</span>,
#  <span class="top_tag">, Zombies</span>,
#  <span class="top_tag">, Multiplayer</span>,
#  <span class="top_tag">Co-op</span>,
#  <span class="top_tag">, Multiplayer</span>,
#  <span class="top_tag">, Action</span>,
#  <span class="top_tag">, Open World</span>,
#  <span class="top_tag">Open World</span>,
#  <span class="top_tag">, Action</span>,
#  <span class="top_tag">, Multiplayer</span>,
#  <span class="top_tag">, Automobile Sim</span>,
#  <span class="top_tag">FPS</span>,
#  <span class="top_tag">, Shooter</span>,
#  <span class="top_tag">, Multiplayer</span>,
#  <span class="top_tag">, Competitive</span>,
#  <span class="top_tag">FPS</span>,
#  <span class="top_tag">, Hero Shooter</span>,
#  <span class="top_tag">, Multiplayer</span>,
#  <span class="top_tag">, Tactical</span>,
#  <span class="top_tag">Free to Play</span>,
#  <span class="top_tag">, Looter Shooter</span>,
#  <span class="top_tag">, FPS</span>,
#  <span class="top_tag">, Multiplayer</span>,
#  <span class="top_tag">Survival</span>,
#  <span class="top_tag">, Shooter</span>,
#  <span class="top_tag">, Multiplayer</span>,
#  <span class="top_tag">, Battle Royale</span>,
#  <span class="top_tag">Action</span>,
#  <span class="top_tag">, FPS</span>,
#  <span class="top_tag">, Multiplayer</span>,
#  <span class="top_tag">, Shooter</span>,
#  <span class="top_tag">Free to Play</span>,
#  <span class="top_tag">, Looter Shooter</span>,
#  <span class="top_tag">, Action</span>,
#  <span class="top_tag">, Co-op</span>,
#  <span class="top_tag">Free to Play</span>,
#  <span class="top_tag">, MOBA</span>,
#  <span class="top_tag">, Multiplayer</span>,
#  <span class="top_tag">, Strategy</span>,
#  <span class="top_tag">RPG</span>,
#  <span class="top_tag">, Action</span>,
#  <span class="top_tag">, Online Co-Op</span>,
#  <span class="top_tag">, Looter Shooter</span>,
#  <span class="top_tag">Multiplayer</span>,
#  <span class="top_tag">, Soccer</span>,
#  <span class="top_tag">, Competitive</span>,
#  <span class="top_tag">, Sports</span>,
#  <span class="top_tag">Free to Play</span>,
#  <span class="top_tag">, Multiplayer</span>,
#  <span class="top_tag">, Fighting</span>,
#  <span class="top_tag">, 2D</span>,
#  <span class="top_tag">Hero Shooter</span>,
#  <span class="top_tag">, Free to Play</span>,
#  <span class="top_tag">, Multiplayer</span>,
#  <span class="top_tag">, FPS</span>,
#  <span class="top_tag">Medieval</span>,
#  <span class="top_tag">, Strategy</span>,
#  <span class="top_tag">, Open World</span>,
#  <span class="top_tag">, RPG</span>,
#  <span class="top_tag">Open World Survival Craft</span>,
#  <span class="top_tag">, Sandbox</span>,
#  <span class="top_tag">, Survival</span>,
#  <span class="top_tag">, 2D</span>,
#  <span class="top_tag">FPS</span>,
#  <span class="top_tag">, Shooter</span>,
#  <span class="top_tag">, Multiplayer</span>,
#  <span class="top_tag">, Competitive</span>,
#  <span class="top_tag">FPS</span>,
#  <span class="top_tag">, Hero Shooter</span>,
#  <span class="top_tag">, Multiplayer</span>,
#  <span class="top_tag">, Tactical</span>,
#  <span class="top_tag">Free to Play</span>,
#  <span class="top_tag">, Looter Shooter</span>,
#  <span class="top_tag">, Action</span>,
#  <span class="top_tag">, Co-op</span>,
#  <span class="top_tag">Zombies</span>,
#  <span class="top_tag">, Co-op</span>,
#  <span class="top_tag">, FPS</span>,
#  <span class="top_tag">, Multiplayer</span>,
#  <span class="top_tag">Action</span>,
#  <span class="top_tag">, FPS</span>,
#  <span class="top_tag">, Multiplayer</span>,
#  <span class="top_tag">, Shooter</span>,
#  <span class="top_tag">Loot</span>,
#  <span class="top_tag">, Shooter</span>,
#  <span class="top_tag">, Action</span>,
#  <span class="top_tag">, Multiplayer</span>,
#  <span class="top_tag">Adventure</span>,
#  <span class="top_tag">, Action</span>,
#  <span class="top_tag">, Female Protagonist</span>,
#  <span class="top_tag">, Third Person</span>,
#  <span class="top_tag">Co-op</span>,
#  <span class="top_tag">, Action</span>,
#  <span class="top_tag">, FPS</span>,
#  <span class="top_tag">, Heist</span>,
#  <span class="top_tag">Free to Play</span>,
#  <span class="top_tag">, Looter Shooter</span>,
#  <span class="top_tag">, FPS</span>,
#  <span class="top_tag">, Multiplayer</span>,
#  <span class="top_tag">Shooter</span>,
#  <span class="top_tag">, Action</span>,
#  <span class="top_tag">, FPS</span>,
#  <span class="top_tag">, Multiplayer</span>,
#  <span class="top_tag">FPS</span>,
#  <span class="top_tag">, Action</span>,
#  <span class="top_tag">, Sci-fi</span>,
#  <span class="top_tag">, Classic</span>,
#  <span class="top_tag">FPS</span>,
#  <span class="top_tag">, Story Rich</span>,
#  <span class="top_tag">, Action</span>,
#  <span class="top_tag">, Singleplayer</span>,
#  <span class="top_tag">Third-Person Shooter</span>,
#  <span class="top_tag">, Action Roguelike</span>,
#  <span class="top_tag">, Action</span>,
#  <span class="top_tag">, Multiplayer</span>,
#  <span class="top_tag">Medieval</span>,
#  <span class="top_tag">, RPG</span>,
#  <span class="top_tag">, Open World</span>,
#  <span class="top_tag">, Strategy</span>,
#  <span class="top_tag">Co-op</span>,
#  <span class="top_tag">, Multiplayer</span>,
#  <span class="top_tag">, Action</span>,
#  <span class="top_tag">, Open World</span>,
#  <span class="top_tag">Adventure</span>,
#  <span class="top_tag">, Action</span>,
#  <span class="top_tag">, Open World</span>,
#  <span class="top_tag">, Pirates</span>,
#  <span class="top_tag">Free to Play</span>,
#  <span class="top_tag">, Action</span>,
#  <span class="top_tag">, Shooter</span>,
#  <span class="top_tag">, Hero Shooter</span>,
#  <span class="top_tag">Massively Multiplayer</span>,
#  <span class="top_tag">, RPG</span>,
#  <span class="top_tag">, Action</span>,
#  <span class="top_tag">, Violent</span>,
#  <span class="top_tag">Adventure</span>,
#  <span class="top_tag">, Action</span>,
#  <span class="top_tag">, Exploration</span>,
#  <span class="top_tag">, Space</span>,
#  <span class="top_tag">Strategy</span>,
#  <span class="top_tag">, Simulation</span>,
#  <span class="top_tag">, Action</span>,
#  <span class="top_tag">, Indie</span>,
#  <span class="top_tag">Action</span>,
#  <span class="top_tag">, Free to Play</span>,
#  <span class="top_tag">, Massively Multiplayer</span>,
#  <span class="top_tag">, Multiplayer</span>,
#  <span class="top_tag">Action</span>,
#  <span class="top_tag">, Violent</span>,
#  <span class="top_tag">, Cyberpunk</span>,
#  <span class="top_tag">, First-Person</span>,
#  <span class="top_tag">Adventure</span>,
#  <span class="top_tag">, Action</span>,
#  <span class="top_tag">, RPG</span>,
#  <span class="top_tag">, Open World</span>,
#  <span class="top_tag">Action</span>,
#  <span class="top_tag">, Zombies</span>,
#  <span class="top_tag">, Open World</span>,
#  <span class="top_tag">, Multiplayer</span>,
#  <span class="top_tag">Cyberpunk</span>,
#  <span class="top_tag">, Masterpiece</span>,
#  <span class="top_tag">, Open World</span>,
#  <span class="top_tag">, RPG</span>,
#  <span class="top_tag">Action</span>,
#  <span class="top_tag">, Adventure</span>,
#  <span class="top_tag">, Indie</span>,
#  <span class="top_tag">, Rhythm</span>,
#  <span class="top_tag">Casual</span>,
#  <span class="top_tag">, Indie</span>,
#  <span class="top_tag">, Simulation</span>,
#  <span class="top_tag">, Action</span>,
#  <span class="top_tag">Indie</span>,
#  <span class="top_tag">, Action</span>,
#  <span class="top_tag">, Violent</span>,
#  <span class="top_tag">, Pixel Graphics</span>,
#  <span class="top_tag">Action</span>,
#  <span class="top_tag">, RPG</span>,
#  <span class="top_tag">, Adventure</span>,
#  <span class="top_tag">, Strategy</span>,
#  <span class="top_tag">RPG</span>,
#  <span class="top_tag">, Adventure</span>,
#  <span class="top_tag">, Action</span>,
#  <span class="top_tag">, Hack and Slash</span>]

# %%
span_top_tags_text = [tag.text.strip(', ') for tag in span_top_tags]
span_top_tags_text
# Out:
# ['Action',
#  'Indie',
#  "Beat 'em up",
#  'Adventure',
#  'Adventure',
#  'RPG',
#  'Massively Multiplayer',
#  'Action',
#  'Action',
#  'Indie',
#  'Adventure',
#  'RPG',
#  'Action',
#  'Indie',
#  'Retro',
#  'Old School',
#  'Indie',
#  'Action',
#  'Adventure',
#  'Gore',
#  'Action',
#  'Indie',
#  'RPG',
#  'Violent',
#  'Free to Play',
#  'Massively Multiplayer',
#  'Action',
#  'Strategy',
#  'Simulation',
#  'Action',
#  'Indie',
#  'Adventure',
#  'Casual',
#  'Indie',
#  'Action',
#  'Simulation',
#  'Action',
#  'Adventure',
#  'Indie',
#  'Gore',
#  'Massively Multiplayer',
#  'Simulation',
#  'Action',
#  'VR',
#  'RPG',
#  'Action',
#  'Online Co-Op',
#  'Looter Shooter',
#  'Action',
#  'Zombies',
#  'Horror',
#  'Female Protagonist',
#  'Action',
#  'Anime',
#  'Fighting',
#  '2D Fighter',
#  'Action',
#  'Adventure',
#  'Nudity',
#  'Early Access',
#  'Action',
#  'Multiplayer',
#  'Hunting',
#  'Co-op',
#  'Action',
#  'Indie',
#  "Beat 'em up",
#  'Adventure',
#  'RPG',
#  'Action',
#  'Online Co-Op',
#  'Looter Shooter',
#  'Co-op',
#  'Multiplayer',
#  'Action',
#  'Open World',
#  'Action',
#  'Masterpiece',
#  'FPS',
#  'Great Soundtrack',
#  'Action',
#  'Anime',
#  'Fighting',
#  '2D Fighter',
#  'Open World',
#  'Action',
#  'Multiplayer',
#  'Automobile Sim',
#  'Adventure',
#  'Action',
#  'Open World',
#  'Masterpiece',
#  'Action Roguelike',
#  'Action',
#  'RPG',
#  'Indie',
#  'Souls-like',
#  'Action',
#  'RPG',
#  'Adventure',
#  'Action',
#  'Zombies',
#  'Horror',
#  'Female Protagonist',
#  'Action',
#  'Multiplayer',
#  'FPS',
#  'Shooter',
#  'Action',
#  'Adventure',
#  'Star Wars',
#  'Souls-like',
#  'Masterpiece',
#  'Action',
#  'Adventure',
#  'VR',
#  'Action',
#  'FPS',
#  'Zombies',
#  'Multiplayer',
#  'Co-op',
#  'Multiplayer',
#  'Action',
#  'Open World',
#  'Open World',
#  'Action',
#  'Multiplayer',
#  'Automobile Sim',
#  'FPS',
#  'Shooter',
#  'Multiplayer',
#  'Competitive',
#  'FPS',
#  'Hero Shooter',
#  'Multiplayer',
#  'Tactical',
#  'Free to Play',
#  'Looter Shooter',
#  'FPS',
#  'Multiplayer',
#  'Survival',
#  'Shooter',
#  'Multiplayer',
#  'Battle Royale',
#  'Action',
#  'FPS',
#  'Multiplayer',
#  'Shooter',
#  'Free to Play',
#  'Looter Shooter',
#  'Action',
#  'Co-op',
#  'Free to Play',
#  'MOBA',
#  'Multiplayer',
#  'Strategy',
#  'RPG',
#  'Action',
#  'Online Co-Op',
#  'Looter Shooter',
#  'Multiplayer',
#  'Soccer',
#  'Competitive',
#  'Sports',
#  'Free to Play',
#  'Multiplayer',
#  'Fighting',
#  '2D',
#  'Hero Shooter',
#  'Free to Play',
#  'Multiplayer',
#  'FPS',
#  'Medieval',
#  'Strategy',
#  'Open World',
#  'RPG',
#  'Open World Survival Craft',
#  'Sandbox',
#  'Survival',
#  '2D',
#  'FPS',
#  'Shooter',
#  'Multiplayer',
#  'Competitive',
#  'FPS',
#  'Hero Shooter',
#  'Multiplayer',
#  'Tactical',
#  'Free to Play',
#  'Looter Shooter',
#  'Action',
#  'Co-op',
#  'Zombies',
#  'Co-op',
#  'FPS',
#  'Multiplayer',
#  'Action',
#  'FPS',
#  'Multiplayer',
#  'Shooter',
#  'Loot',
#  'Shooter',
#  'Action',
#  'Multiplayer',
#  'Adventure',
#  'Action',
#  'Female Protagonist',
#  'Third Person',
#  'Co-op',
#  'Action',
#  'FPS',
#  'Heist',
#  'Free to Play',
#  'Looter Shooter',
#  'FPS',
#  'Multiplayer',
#  'Shooter',
#  'Action',
#  'FPS',
#  'Multiplayer',
#  'FPS',
#  'Action',
#  'Sci-fi',
#  'Classic',
#  'FPS',
#  'Story Rich',
#  'Action',
#  'Singleplayer',
#  'Third-Person Shooter',
#  'Action Roguelike',
#  'Action',
#  'Multiplayer',
#  'Medieval',
#  'RPG',
#  'Open World',
#  'Strategy',
#  'Co-op',
#  'Multiplayer',
#  'Action',
#  'Open World',
#  'Adventure',
#  'Action',
#  'Open World',
#  'Pirates',
#  'Free to Play',
#  'Action',
#  'Shooter',
#  'Hero Shooter',
#  'Massively Multiplayer',
#  'RPG',
#  'Action',
#  'Violent',
#  'Adventure',
#  'Action',
#  'Exploration',
#  'Space',
#  'Strategy',
#  'Simulation',
#  'Action',
#  'Indie',
#  'Action',
#  'Free to Play',
#  'Massively Multiplayer',
#  'Multiplayer',
#  'Action',
#  'Violent',
#  'Cyberpunk',
#  'First-Person',
#  'Adventure',
#  'Action',
#  'RPG',
#  'Open World',
#  'Action',
#  'Zombies',
#  'Open World',
#  'Multiplayer',
#  'Cyberpunk',
#  'Masterpiece',
#  'Open World',
#  'RPG',
#  'Action',
#  'Adventure',
#  'Indie',
#  'Rhythm',
#  'Casual',
#  'Indie',
#  'Simulation',
#  'Action',
#  'Indie',
#  'Action',
#  'Violent',
#  'Pixel Graphics',
#  'Action',
#  'RPG',
#  'Adventure',
#  'Strategy',
#  'RPG',
#  'Adventure',
#  'Action',
#  'Hack and Slash']

# %% [markdown]
# ### Under the "Narrow by Tag" section, there are a collection of tags (e.g. "Indie", "Adventure", etc.). Write code to return these tags.
#
# It comes under `a` tag with class = `"btnv6_blue_hoverfade btn_small_tall"`

# %%
narrow_by_tags = soup.find_all('a', {'class':'btnv6_blue_hoverfade btn_small_tall'})
narrow_by_tags
# Out:
# [<a class="btnv6_blue_hoverfade btn_small_tall" href="https://store.steampowered.com/search/?tags=492,19&amp;snr=1_241_4_action_237">
#  <span>
#  <div class="tag_count_button">
#  <span class="tag_name">Indie</span>
#  <span class="tag_count tab_filter_control_count">15,008</span>
#  </div>
#  </span>
#  </a>,
#  <a class="btnv6_blue_hoverfade btn_small_tall" href="https://store.steampowered.com/search/?tags=21,19&amp;snr=1_241_4_action_237">
#  <span>
#  <div class="tag_count_button">
#  <span class="tag_name">Adventure</span>
#  <span class="tag_count tab_filter_control_count">8,152</span>
#  </div>
#  </span>
#  </a>,
#  <a class="btnv6_blue_hoverfade btn_small_tall" href="https://store.steampowered.com/search/?tags=597,19&amp;snr=1_241_4_action_237">
#  <span>
#  <div class="tag_count_button">
#  <span class="tag_name">Casual</span>
#  <span class="tag_count tab_filter_control_count">5,963</span>
#  </div>
#  </span>
#  </a>,
#  <a class="btnv6_blue_hoverfade btn_small_tall" href="https://store.steampowered.com/search/?tags=4182,19&amp;snr=1_241_4_action_237">
#  <span>
#  <div class="tag_count_button">
#  <span class="tag_name">Singleplayer</span>
#  <span class="tag_count tab_filter_control_count">5,025</span>
#  </div>
#  </span>
#  </a>,
#  <a class="btnv6_blue_hoverfade btn_small_tall" href="https://store.steampowered.com/search/?tags=122,19&amp;snr=1_241_4_action_237">
#  <span>
#  <div class="tag_count_button">
#  <span class="tag_name">RPG</span>
#  <span class="tag_count tab_filter_control_count">3,387</span>
#  </div>
#  </span>
#  </a>,
#  <a class="btnv6_blue_hoverfade btn_small_tall" href="https://store.steampowered.com/search/?tags=493,19&amp;snr=1_241_4_action_237">
#  <span>
#  <div class="tag_count_button">
#  <span class="tag_name">Early Access</span>
#  <span class="tag_count tab_filter_control_count">3,241</span>
#  </div>
#  </span>
#  </a>,
#  <a class="btnv6_blue_hoverfade btn_small_tall" href="https://store.steampowered.com/search/?tags=599,19&amp;snr=1_241_4_action_237">
#  <span>
#  <div class="tag_count_button">
#  <span class="tag_name">Simulation</span>
#  <span class="tag_count tab_filter_control_count">2,887</span>
#  </div>
#  </span>
#  </a>,
#  <a class="btnv6_blue_hoverfade btn_small_tall" href="https://store.steampowered.com/search/?tags=9,19&amp;snr=1_241_4_action_237">
#  <span>
#  <div class="tag_count_button">
#  <span class="tag_name">Strategy</span>
#  <span class="tag_count tab_filter_control_count">2,861</span>
#  </div>
#  </span>
#  </a>,
#  <a class="btnv6_blue_hoverfade btn_small_tall" href="https://store.steampowered.com/search/?tags=3859,19&amp;snr=1_241_4_action_237">
#  <span>
#  <div class="tag_count_button">
#  <span class="tag_name">Multiplayer</span>
#  <span class="tag_count tab_filter_control_count">2,693</span>
#  </div>
#  </span>
#  </a>,
#  <a class="btnv6_blue_hoverfade btn_small_tall" href="https://store.steampowered.com/search/?tags=3871,19&amp;snr=1_241_4_action_237">
#  <span>
#  <div class="tag_count_button">
#  <span class="tag_name">2D</span>
#  <span class="tag_count tab_filter_control_count">2,615</span>
#  </div>
#  </span>
#  </a>,
#  <a class="btnv6_blue_hoverfade btn_small_tall" href="https://store.steampowered.com/search/?tags=4667,19&amp;snr=1_241_4_action_237">
#  <span>
#  <div class="tag_count_button">
#  <span class="tag_name">Violent</span>
#  <span class="tag_count tab_filter_control_count">2,306</span>
#  </div>
#  </span>
#  </a>,
#  <a class="btnv6_blue_hoverfade btn_small_tall" href="https://store.steampowered.com/search/?tags=1774,19&amp;snr=1_241_4_action_237">
#  <span>
#  <div class="tag_count_button">
#  <span class="tag_name">Shooter</span>
#  <span class="tag_count tab_filter_control_count">2,266</span>
#  </div>
#  </span>
#  </a>]

# %%
narrow_by_text = [tag.find('span', class_ = 'tag_name').text
                  for tag in narrow_by_tags]
narrow_by_text
# Out:
# ['Indie',
#  'Adventure',
#  'Casual',
#  'Singleplayer',
#  'RPG',
#  'Early Access',
#  'Simulation',
#  'Strategy',
#  'Multiplayer',
#  '2D',
#  'Violent',
#  'Shooter']

# %% [markdown]
# ### Extra scraping
#
# We can extract the game tag related to our top games list.

# %%
top_rated_game_tags = [game.find('div', class_ = 'tab_item_top_tags').text
                       for game in top_rated]
top_rated_game_tags
# Out:
# ['FPS, Shooter, Multiplayer, Competitive',
#  'FPS, Hero Shooter, Multiplayer, Tactical',
#  'Free to Play, Looter Shooter, Action, Co-op',
#  'Zombies, Co-op, FPS, Multiplayer',
#  'Action, FPS, Multiplayer, Shooter',
#  'Loot, Shooter, Action, Multiplayer',
#  'Adventure, Action, Female Protagonist, Third Person',
#  'Co-op, Action, FPS, Heist',
#  'Free to Play, Looter Shooter, FPS, Multiplayer',
#  'Shooter, Action, FPS, Multiplayer',
#  'FPS, Action, Sci-fi, Classic',
#  'FPS, Story Rich, Action, Singleplayer',
#  'Third-Person Shooter, Action Roguelike, Action, Multiplayer',
#  'Medieval, RPG, Open World, Strategy',
#  'Co-op, Multiplayer, Action, Open World']

# %% [markdown]
# ### Create namedtuple and dataframe for top rated games attributes
#
# top_rated_games
#
# top_rated_prices
#
# top_rated_game_tags

# %%
from collections import namedtuple
import pandas as pd

# %%
top_games = namedtuple('TopGames','Name Price Category')

# %%
for data in zip(top_rated_games, top_rated_prices, top_rated_game_tags):
    print(top_games(*data))
# Out:
# Top_games(Name='Counter-Strike: Global Offensive', Price='Free to Play', Category='FPS, Shooter, Multiplayer, Competitive')
# Top_games(Name="Tom Clancy's Rainbow Six® Siege", Price='₹ 999', Category='FPS, Hero Shooter, Multiplayer, Tactical')
# Top_games(Name='Warframe', Price='Free to Play', Category='Free to Play, Looter Shooter, Action, Co-op')
# Top_games(Name='Left 4 Dead 2', Price='₹ 349', Category='Zombies, Co-op, FPS, Multiplayer')
# Top_games(Name='Counter-Strike', Price='₹ 349', Category='Action, FPS, Multiplayer, Shooter')
# Top_games(Name='Borderlands 2', Price='₹ 999', Category='Loot, Shooter, Action, Multiplayer')
# Top_games(Name='Tomb Raider', Price=None, Category='Adventure, Action, Female Protagonist, Third Person')
# Top_games(Name='PAYDAY 2', Price='₹ 349', Category='Co-op, Action, FPS, Heist')
# Top_games(Name='Destiny 2', Price='Free To Play', Category='Free to Play, Looter Shooter, FPS, Multiplayer')
# Top_games(Name='Counter-Strike: Source', Price='₹ 349', Category='Shooter, Action, FPS, Multiplayer')
# Top_games(Name='Half-Life 2', Price='₹ 349', Category='FPS, Action, Sci-fi, Classic')
# Top_games(Name='BioShock Infinite', Price='₹ 1,499', Category='FPS, Story Rich, Action, Singleplayer')
# Top_games(Name='Risk of Rain 2', Price='₹ 719', Category='Third-Person Shooter, Action Roguelike, Action, Multiplayer')
# Top_games(Name='Mount & Blade: Warband', Price='₹ 699', Category='Medieval, RPG, Open World, Strategy')
# Top_games(Name='MONSTER HUNTER: WORLD', Price='₹ 2,497', Category='Co-op, Multiplayer, Action, Open World')

# %%
df = pd.DataFrame({
    'Name':top_rated_games,
    'Price':top_rated_prices,
    'Category':top_rated_game_tags
})

# %%
df
# Out:
#                                 Name         Price  \
# 0   Counter-Strike: Global Offensive  Free to Play
# 1    Tom Clancy's Rainbow Six® Siege         ₹ 999
# 2                           Warframe  Free to Play
# 3                      Left 4 Dead 2         ₹ 349
# 4                     Counter-Strike         ₹ 349
# 5                      Borderlands 2         ₹ 999
# 6                        Tomb Raider          None
# 7                           PAYDAY 2         ₹ 349
# 8                          Destiny 2  Free To Play
# 9             Counter-Strike: Source         ₹ 349
# 10                       Half-Life 2         ₹ 349
# 11                 BioShock Infinite       ₹ 1,499
# 12                    Risk of Rain 2         ₹ 719
# 13            Mount & Blade: Warband         ₹ 699
# 14             MONSTER HUNTER: WORLD       ₹ 2,497
#
#                                              Category
# 0              FPS, Shooter, Multiplayer, Competitive
# 1            FPS, Hero Shooter, Multiplayer, Tactical
# 2         Free to Play, Looter Shooter, Action, Co-op
# 3                    Zombies, Co-op, FPS, Multiplayer
# 4                   Action, FPS, Multiplayer, Shooter
# 5                  Loot, Shooter, Action, Multiplayer
# 6   Adventure, Action, Female Protagonist, Third P...
# 7                           Co-op, Action, FPS, Heist
# 8      Free to Play, Looter Shooter, FPS, Multiplayer
# 9                   Shooter, Action, FPS, Multiplayer
# 10                       FPS, Action, Sci-fi, Classic
# 11              FPS, Story Rich, Action, Singleplayer
# 12  Third-Person Shooter, Action Roguelike, Action...
# 13                Medieval, RPG, Open World, Strategy
# 14             Co-op, Multiplayer, Action, Open World

# %%
df.sort_values('Price', ascending=False)
# Out:
#                                 Name         Price  \
# 1    Tom Clancy's Rainbow Six® Siege         ₹ 999
# 5                      Borderlands 2         ₹ 999
# 12                    Risk of Rain 2         ₹ 719
# 13            Mount & Blade: Warband         ₹ 699
# 3                      Left 4 Dead 2         ₹ 349
# 4                     Counter-Strike         ₹ 349
# 7                           PAYDAY 2         ₹ 349
# 9             Counter-Strike: Source         ₹ 349
# 10                       Half-Life 2         ₹ 349
# 14             MONSTER HUNTER: WORLD       ₹ 2,497
# 11                 BioShock Infinite       ₹ 1,499
# 0   Counter-Strike: Global Offensive  Free to Play
# 2                           Warframe  Free to Play
# 8                          Destiny 2  Free To Play
# 6                        Tomb Raider          None
#
#                                              Category
# 1            FPS, Hero Shooter, Multiplayer, Tactical
# 5                  Loot, Shooter, Action, Multiplayer
# 12  Third-Person Shooter, Action Roguelike, Action...
# 13                Medieval, RPG, Open World, Strategy
# 3                    Zombies, Co-op, FPS, Multiplayer
# 4                   Action, FPS, Multiplayer, Shooter
# 7                           Co-op, Action, FPS, Heist
# 9                   Shooter, Action, FPS, Multiplayer
# 10                       FPS, Action, Sci-fi, Classic
# 14             Co-op, Multiplayer, Action, Open World
# 11              FPS, Story Rich, Action, Singleplayer
# 0              FPS, Shooter, Multiplayer, Competitive
# 2         Free to Play, Looter Shooter, Action, Co-op
# 8      Free to Play, Looter Shooter, FPS, Multiplayer
# 6   Adventure, Action, Female Protagonist, Third P...
